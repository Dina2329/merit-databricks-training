# %%
type(spark)

# %% [markdown]
# ##  Create A dataframe reader

# %% [markdown]
# # Create DF From Different source

# %%
df = spark.read
print(df)

# %% [markdown]
# ### csv
# Header for header
# inferSchema for datatype

# %%
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header=True,inferSchema=True)
df.display()

# %%
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",sep="|", header=True,inferSchema=True)
df.display()

# %% [markdown]
# JSON

# %% [markdown]
# If Each line is json

# %%
df = spark.read.json(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json").display()

# %% [markdown]
# if json is in mutliline we need to use variable multiline = True and if it has multiple records in file as multiline it must inside []

# %%
df = spark.read.json(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json",multiLine=True).display()

# %% [markdown]
# Parquet

# %%
df = spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users.parquet").display()

# %% [markdown]
# ## Custom Schema

# %%
from pyspark.sql.types import *

userschema = StructType([
    StructField("id", IntegerType(), True),
    StructField("age", IntegerType(), True),
    StructField("gender", StringType(), True),
    StructField("designation", StringType(), True),
    StructField("salary", IntegerType(), True)
])
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat",sep="|", header=True,schema=userschema)
df.display()

# %% [markdown]
# ## Handling Bad Records
#
# - Permissive(default) automatical go _corrupted_column
# - Dropmalformed
# - Failfast

# %%
df = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/access_logs.json").display()

# %%
df = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode="DROPMALFORMED").display()

# %%
df = spark.read.json("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/access_logs.json",mode="FAILFAST").display()

# %% [markdown]
# Dataframe Writer API

# %%
df = spark.read.csv("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header=True,inferSchema=True)


df.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet"
              )
spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet").display()

# %% [markdown]
# ## MODES
#
# - errorifExist
# - OVERWRITE
# - Append
# - Ignore

# %%
df.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet"
              )

# %%
df.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet",mode="overwrite" )

# %%
df.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet",mode="append")

# %%
df.write.save(format="parquet",path="/Volumes/merit_catalog/quickstart_schema/sandbox/output_parquet",mode="ignore")
