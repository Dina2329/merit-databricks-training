# %% [markdown]
# # Prerequeities

# %%
df = spark.read.csv(path="/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",header=True, inferSchema=True)
df.limit(4).display()

# %%
df.write.format("parquet").save("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/output_parquet",mode="overwrite")

df_parquet=spark.read.parquet("/Volumes/merit_catalog/quickstart_schema/sandbox/dataset/output_parquet").limit(4).display()
